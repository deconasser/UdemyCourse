# %% [markdown]
# <a href="https://colab.research.google.com/github/deconasser/UdemyCourse/blob/main/Jose%20Portilla%2C%20Plerian%20Training/Section2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
data = Image.open("cat")
data_arr = np.asarray(data).copy()
print(data_arr.shape)
# Out:
# (1602, 1200, 3)

# %%
data_arr[:,:, 1] = 0
plt.imshow(data_arr)

# %%
arr = np.ones((5,5))
print(arr*10)
# Out:
# [[10. 10. 10. 10. 10.]
#  [10. 10. 10. 10. 10.]
#  [10. 10. 10. 10. 10.]
#  [10. 10. 10. 10. 10.]
#  [10. 10. 10. 10. 10.]]

# %%
np.random.seed(101)
arr = np.random.randint(low=0, high=100, size=(5,5))

# %%
print(arr)
# Out:
# [[95 11 81 70 63]
#  [87 75  9 77 40]
#  [ 4 63 40 60 92]
#  [64  5 12 93 40]
#  [49 83  8 29 59]]

# %%
print(arr)
# Out:
# [[95 11 81 70 63]
#  [87 75  9 77 40]
#  [ 4 63 40 60 92]
#  [64  5 12 93 40]
#  [49 83  8 29 59]]

# %%
print(arr.max(), arr.argmin())
# Out:
# 95 10

# %%
img = Image.open("/content/49er decal.jpeg")
plt.imshow(img)
img = np.asarray(img)
print(img.shape)
# Out:
# (900, 900, 3)
