# %% [markdown]
# <a href="https://colab.research.google.com/github/deconasser/UdemyCourse/blob/main/Jose%20Portilla%2C%20Plerian%20Training/Chapter4_Gradient_Edge_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
def display_img(img):
  fig = plt.figure(figsize=(10,10))
  ax = fig.add_subplot(111)
  ax.imshow(img, cmap="gray")

# %%
img = cv2.imread("/content/sudoku.jpg", 0)
display_img(img)

# %%
sobelx = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)
display_img(sobelx)

# %%
sobely = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)
display_img(sobely)

# %%
laplacian = cv2.Laplacian(img, cv2.CV_64F)
display_img(laplacian)

# %%
blended = (0.5 * sobelx) + (0.5 * sobely)
display_img(blended)
